# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/haukur/miniconda3/lib/python3.9/site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/haukur/miniconda3/lib/python3.9/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/haukur/miniconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/haukur/miniconda3/lib/python3.9/site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/haukur/miniconda3/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /home/haukur/miniconda3/lib/python3.9/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /home/haukur/miniconda3/lib/python3.9/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/haukur/miniconda3/lib/python3.9/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/haukur/miniconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/haukur/miniconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/haukur/miniconda3/lib/python3.9/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/haukur/miniconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in /home/haukur/miniconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the CSV file into a DataFrame
data = pd.read_csv("data.csv")

# Extract the date and amount of accidents columns
dates = data["Date"]

# Convert the dates to datetime objects
dates = pd.to_datetime(dates)
print(dates)
accidents = data["Amount of accidents"]
# Out:
# 0     2009-01-01
# 1     2009-02-01
# 2     2009-03-01
# 3     2009-12-01
# 4     2009-04-01
#          ...
# 163   2022-08-01
# 164   2022-09-01
# 165   2022-10-01
# 166   2022-11-01
# 167   2022-12-01
# Name: Date, Length: 168, dtype: datetime64[ns]

# %%
# Plot the data
plt.scatter(dates, accidents)
plt.xlabel("Date")
plt.ylabel("Amount of Accidents")
plt.title("Accident Data Over Time")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust spacing
plt.show()

# %%
# Plot the data
plt.plot(dates, accidents)
plt.xlabel("Date")
plt.ylabel("Amount of Accidents")
plt.title("Accident Data Over Time")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust spacing
plt.show()
